# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
# data training
X = pd.DataFrame([
    # x1, x2, y
    [2, 5, 4],
    [2.3, 3, 5],
    [4, 5, 7],
    [3, 3, 6]
], columns = ['x1', 'x2', 'y'])
y = X.pop('y')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# initialize model
lr = LinearRegression()
# train model
lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.scatter(X['x1'], X['x2'], y, label='parametric curve')

ax.plot(X['x1'], X['x2'], y_pred, color='blue', linewidth=3)
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# get data to test
test = np.array([
    # x1, x2
    [2, 5],
    [2.3, 4],
    [4, 7]
])

# %%
# create function to predict
f = lambda x: lr.predict([x])
result = np.array(list(map(f, test)))
result
# Out:
# array([[4.   ],
#        [4.725],
#        [6.45 ]])

# %%
fig= plt.figure()
plt.show()
